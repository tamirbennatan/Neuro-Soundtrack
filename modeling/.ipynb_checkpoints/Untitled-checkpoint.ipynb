# %%
import numpy as np
import pandas as pd
import pickle as pkl

from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input, Dense, LSTM, Dropout, Merge, LocallyConnected2D,Reshape, Conv2D, MaxPooling2D, Flatten,Concatenate
from keras.layers.merge import add, concatenate
# from keras.callbacks import ModelCheckpoint
# from keras.optimizers import SGD

# %%
help (MaxPooling2D)
# Out:
# Help on class MaxPooling2D in module keras.layers.pooling:
#
# class MaxPooling2D(_Pooling2D)
#  |  Max pooling operation for spatial data.
#  |
#  |  # Arguments
#  |      pool_size: integer or tuple of 2 integers,
#  |          factors by which to downscale (vertical, horizontal).
#  |          (2, 2) will halve the input in both spatial dimension.
#  |          If only one integer is specified, the same window length
#  |          will be used for both dimensions.
#  |      strides: Integer, tuple of 2 integers, or None.
#  |          Strides values.
#  |          If None, it will default to `pool_size`.
#  |      padding: One of `"valid"` or `"same"` (case-insensitive).
#  |      data_format: A string,
#  |          one of `channels_last` (default) or `channels_first`.
#  |          The ordering of the dimensions in the inputs.
#  |          `channels_last` corresponds to inputs with shape
#  |          `(batch, height, width, channels)` while `channels_first`
# ...

# %%
# inputs
# blur_input = Input(shape = (166, 165,1), name = "BlurInput")
# edges_input = Input(shape = (166, 165,1), name = "EdgesInput")

# # locally connected layers
# blur_local = LocallyConnected2D(8, (3,3),activation="relu")(blur_input)
# blur_conv = Conv2D(16, (3,3),activation="relu")(blur_local)
# edges_local = LocallyConnected2D(8, (3,3),activation="relu")(edges_input)
# edges_conv = Conv2D(16,(3,3),activation="relu")(edges_local)

# # add maxpooling layers to convoutions
# blur_conv_pool = MaxPooling2D(pool_size = (3,3))(blur_conv)
# edges_conv_pool = MaxPooling2D(pool_size = (3,3))(edges_conv)


# # flatten convolutions
# flat_local_blur = Flatten()(blur_local)
# flat_local_edges = Flatten()(edges_local)
# flat_conv_blur = Flatten()(blur_conv_pool)
# flat_conv_edges = Flatten()(edges_conv_pool)

# put the conv layers together, and the locally connected layers togethe
conv_layers = Concatenate(axis = 1)([flat_conv_blur,flat_conv_edges])
out = Reshape((45792,2,-1))(conv_layers)
lstm_conv = LSTM(300)(out)
# # add LSTM layers
# lstm_local_blur = LSTM(300,activation = "relu")(flat_local_blur)
# lstm_local_edges = LSTM(300,activation = "relu")(flat_local_edges)
# lstm_conv_blur = LSTM(300,activation = "relu")(flat_conv_blur)
# lstm_conv_edges = LSTM(300,activation = "relu")(flat_conv_edges)

# # Merge
# merged = concatenate([lstm_local_blur,lstm_local_edges,lstm_conv_blur,lstm_conv_edges])

# predict
# output = LSTM(88200,activation = "linear")(flat_local_blur)

# model
model = Model(inputs=[blur_input,edges_input], outputs=out)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-3ec6844b4508> in <module>()
#      23 conv_layers = Concatenate(axis = 1)([flat_conv_blur,flat_conv_edges])
#      24 out = Reshape((45792,2,-1))(conv_layers)
# ---> 25 lstm_conv = LSTM(300)(out)
#      26 # # add LSTM layers
#      27 # lstm_local_blur = LSTM(300,activation = "relu")(flat_local_blur)
#
# /usr/local/lib/python3.6/site-packages/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     497
#     498         if initial_state is None and constants is None:
# --> 499             return super(RNN, self).__call__(inputs, **kwargs)
#     500
#     501         # If any of `initial_state` or `constants` are specified and are Keras
#
# /usr/local/lib/python3.6/site-packages/keras/engine/topology.py in __call__(self, inputs, **kwargs)
# ...

# %%
# create an optimizer
sgd = optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True)
model.compile(loss='mean_squared_error', optimizer=sgd)

# %%
ls ../data/signals | grep song_200
# Out:
# song_200_snippet_10signal.npy
# song_200_snippet_1signal.npy
# song_200_snippet_2signal.npy
# song_200_snippet_3signal.npy
# song_200_snippet_4signal.npy
# song_200_snippet_5signal.npy
# song_200_snippet_6signal.npy
# song_200_snippet_7signal.npy
# song_200_snippet_8signal.npy
# song_200_snippet_9signal.npy

# %%
np.load('../data/signals/song_200_snippet_10signal.npy').shape
# Out:
# (88200,)

# %%
np.load('../data/blurs/song_200_snippet_10blur.npy').shape
# Out:
# (166, 165)
