# %%
import numpy as np
from pydub import AudioSegment
import audiosegment
import cv2
import pdb
import os

import pickle as pkl

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2
from utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# directory where all my music lives
MUSIC_DIR = '/Users/timibennatan/Music/iTunes/iTunes Media/Music/**'
SNIPPETS_PER_SONG = 30 # extract 30 one second snippet from each song

# # create a generator of audiosegments for each song
songs = read_songs(MUSIC_DIR)
songs
# Out:
# Found: 3495 Files
# <generator object read_songs.<locals>.<genexpr> at 0x11c05ff68>

# %%
def save_npy(arr,path):
    with(open(path, 'wb')) as handle:
        np.save(handle,arr)

# %%
pooler = get_pooler()
# Out:
# /Users/timibennatan/Desktop/Neuro-Soundtrack/feature_extraction/utils.py:96: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("ma...)`
#   model = Model(inputs = input_img, output = pool)

# %%
# create a generator of audiosegments for each song
songs = read_songs(MUSIC_DIR)

def save_data(printevery = 10, signal_shape = (88200,), spect_shape = (662, 659)):
    song_id = 0
    ids = {}
    for song in songs:
        song_id += 1
        snippet_idx = 0
        # split the song into seconds intervals
        song_split = song.dice(1)
        # randomly sample SNIPPETS_PER_SONG snippets per song
        np.random.seed(song_id + snippet_idx)
        choices = np.random.choice(len(song_split),min(len(song_split),SNIPPETS_PER_SONG), replace = False)
        # iterate through the snippets
        for choice in choices:
            snippet = song_split[choice]
            snippet_idx += 1
            # create an identifier for the song/snippet combination
            snippet_name = "song_%d_snippet_%d"%(song_id,snippet_idx)
            # extract signal
            signal = snippet.to_numpy_array()
            if signal.shape != signal_shape:
                print ("Incorrect signal length on song %d. Skipping"%song_id)
                break
            # extract a spectrogram for the snippet
            _, _, spect = get_spect(snippet)
            if spect_shape != spect_shape:
                print ("Incorrect spectrogram shape on song %d. Skipping"%song_id)
                break
            # normalize to range (0,1)
            spect = normalize_spectogram(spect)
            if spect is None:
                continue
            # blur the spectrogram
            spect_blur = gaussian_blur(spect,window = (3,3))
            # edge detect
            spect_edges = edge_detect(spect,lowerbound = 0, upperbound=200,scale = 255)
            # perform max pooling to reduce dimensionality
            spect_blur = pooler(spect_blur)
            spect_edges = pooler(spect_edges)
            # create names for blurs, edges and signlas
            blur_name = snippet_name + "blur.npy"
            signal_name = snippet_name + "signal.npy"
            edges_name = snippet_name + "edges.npy"
            #add_names and save files
            ids[snippet_name] = {"blur":blur_name, "edges":edges_name, "signal":signal_name}
            save_npy(spect_blur,"../data/blurs/"+blur_name)
            save_npy(spect_edges,"../data/edges/"+edges_name)
            save_npy(signal,"../data/signals/"+signal_name)
        # print ever `print_every` songs
        if song_id % printevery ==0:
            print("Finished: %d" % song_id)
    # save the ids list
    with open("../data/ids_list.pkl","wb") as handle:
        pkl.dump(ids,handle)
    handle.close()

# %time save_data(printevery=10)
# Out:
# Found: 3495 Files
# Incorrect signal length on song 1. Skipping
# Incorrect signal length on song 5. Skipping
# Finished: 10
# Incorrect signal length on song 19. Skipping
# Incorrect signal length on song 20. Skipping
# Finished: 20
# Incorrect signal length on song 21. Skipping
# Incorrect signal length on song 23. Skipping
# Incorrect signal length on song 24. Skipping
# Incorrect signal length on song 30. Skipping
# Finished: 30
# Incorrect signal length on song 32. Skipping
# Incorrect signal length on song 33. Skipping
# Finished: 40
# Incorrect signal length on song 44. Skipping
# Finished: 50
# Finished: 60
# Incorrect signal length on song 62. Skipping
# Incorrect signal length on song 69. Skipping
# Finished: 70
# Incorrect signal length on song 72. Skipping
# Finished: 80
# Finished: 90
# Incorrect signal length on song 95. Skipping
# Finished: 100
# Incorrect signal length on song 110. Skipping
# Finished: 110
# Incorrect signal length on song 118. Skipping
# Finished: 120
# Finished: 130
# Incorrect signal length on song 135. Skipping
# Finished: 140
# Incorrect signal length on song 144. Skipping
# Incorrect signal length on song 148. Skipping
# Finished: 150
# Finished: 160
# Incorrect signal length on song 163. Skipping
# Incorrect signal length on song 168. Skipping
# Incorrect signal length on song 169. Skipping
# Finished: 170
# Incorrect signal length on song 178. Skipping
# Finished: 180
# Finished: 190
# Incorrect signal length on song 195. Skipping
# Incorrect signal length on song 198. Skipping
# Incorrect signal length on song 200. Skipping
# Finished: 200
# Finished: 210
# Incorrect signal length on song 218. Skipping
# Finished: 220
# Incorrect signal length on song 222. Skipping
# Incorrect signal length on song 227. Skipping
# Incorrect signal length on song 229. Skipping
# Finished: 230
# Incorrect signal length on song 235. Skipping
# Incorrect signal length on song 240. Skipping
# Finished: 240
# Incorrect signal length on song 245. Skipping
# Incorrect signal length on song 247. Skipping
# Incorrect signal length on song 249. Skipping
# Finished: 250
# Finished: 260
# Incorrect signal length on song 261. Skipping
# Finished: 270
# Incorrect signal length on song 271. Skipping
# Incorrect signal length on song 275. Skipping
# Finished: 280
# Finished: 290
# Incorrect signal length on song 297. Skipping
# Finished: 300
# Incorrect signal length on song 302. Skipping
# Finished: 310
# Incorrect signal length on song 315. Skipping
# Incorrect signal length on song 319. Skipping
# Finished: 320
# Incorrect signal length on song 323. Skipping
# Finished: 330
# Incorrect signal length on song 340. Skipping
# Finished: 340
# Incorrect signal length on song 350. Skipping
# Finished: 350
# Incorrect signal length on song 355. Skipping
# Finished: 360
# Incorrect signal length on song 370. Skipping
# Finished: 370
# Incorrect signal length on song 372. Skipping
# Incorrect signal length on song 378. Skipping
# Finished: 380
# Incorrect signal length on song 384. Skipping
# Incorrect signal length on song 385. Skipping
# Incorrect signal length on song 386. Skipping
# Incorrect signal length on song 387. Skipping
# Incorrect signal length on song 388. Skipping
# Incorrect signal length on song 389. Skipping
# Finished: 390
# Incorrect signal length on song 394. Skipping
# Incorrect signal length on song 396. Skipping
# Finished: 400
# Incorrect signal length on song 403. Skipping
# Incorrect signal length on song 404. Skipping
# Incorrect signal length on song 405. Skipping
# Finished: 410
# Incorrect signal length on song 416. Skipping
# Incorrect signal length on song 417. Skipping
# Incorrect signal length on song 420. Skipping
# Finished: 420
# Incorrect signal length on song 421. Skipping
# Finished: 430
# Incorrect signal length on song 440. Skipping
# Finished: 440
# Incorrect signal length on song 447. Skipping
# Finished: 450
# Incorrect signal length on song 451. Skipping
# Finished: 460
# Incorrect signal length on song 465. Skipping
# Incorrect signal length on song 466. Skipping
# Incorrect signal length on song 467. Skipping
# Incorrect signal length on song 468. Skipping
# Incorrect signal length on song 470. Skipping
# Finished: 470
# Incorrect signal length on song 472. Skipping
# Finished: 480
# Incorrect signal length on song 483. Skipping
# Incorrect signal length on song 490. Skipping
# Finished: 490
# Incorrect signal length on song 492. Skipping
# Incorrect signal length on song 498. Skipping
# Finished: 500
# Incorrect signal length on song 506. Skipping
# Finished: 510
# Incorrect signal length on song 511. Skipping
# Incorrect signal length on song 515. Skipping
# Incorrect signal length on song 517. Skipping
# Incorrect signal length on song 520. Skipping
# Finished: 520
# Finished: 530
# Finished: 540
# Incorrect signal length on song 543. Skipping
# Incorrect signal length on song 546. Skipping
# Finished: 550
# Incorrect signal length on song 556. Skipping
# Incorrect signal length on song 557. Skipping
# Finished: 560
# Incorrect signal length on song 562. Skipping
# Incorrect signal length on song 565. Skipping
# Finished: 570
# Incorrect signal length on song 573. Skipping
# Incorrect signal length on song 574. Skipping
# Finished: 580
# Finished: 590
# Incorrect signal length on song 600. Skipping
# Finished: 600
# Finished: 610
# Incorrect signal length on song 620. Skipping
# Finished: 620
# Incorrect signal length on song 624. Skipping
# Incorrect signal length on song 627. Skipping
# Incorrect signal length on song 629. Skipping
# Finished: 630
# Incorrect signal length on song 636. Skipping
# Finished: 640
# Finished: 650
# Incorrect signal length on song 655. Skipping
# Finished: 660
# Finished: 670
# Finished: 680
# Incorrect signal length on song 686. Skipping
# Finished: 690
# Incorrect signal length on song 691. Skipping
# Incorrect signal length on song 695. Skipping
# Finished: 700
# Incorrect signal length on song 704. Skipping
# Incorrect signal length on song 708. Skipping
# Finished: 710
# Incorrect signal length on song 713. Skipping
# Finished: 720
# Incorrect signal length on song 722. Skipping
# Incorrect signal length on song 728. Skipping
# Incorrect signal length on song 730. Skipping
# Finished: 730
# Finished: 740
# Incorrect signal length on song 743. Skipping
# Finished: 750
# Incorrect signal length on song 758. Skipping
# Finished: 760
# Incorrect signal length on song 769. Skipping
# Finished: 770
# Incorrect signal length on song 773. Skipping
# Incorrect signal length on song 778. Skipping
# Finished: 780
# Incorrect signal length on song 788. Skipping
# Incorrect signal length on song 790. Skipping
# Finished: 790
# Finished: 800
# Incorrect signal length on song 806. Skipping
# Finished: 810
# Incorrect signal length on song 814. Skipping
# Finished: 820
# Incorrect signal length on song 830. Skipping
# Finished: 830
# Incorrect signal length on song 833. Skipping
# Incorrect signal length on song 835. Skipping
# Incorrect signal length on song 836. Skipping
# Incorrect signal length on song 837. Skipping
# Finished: 840
# Finished: 850
# Incorrect signal length on song 855. Skipping
# Incorrect signal length on song 856. Skipping
# Incorrect signal length on song 858. Skipping
# Finished: 860
# Incorrect signal length on song 861. Skipping
# Finished: 870
# Incorrect signal length on song 871. Skipping
# Incorrect signal length on song 878. Skipping
# Incorrect signal length on song 879. Skipping
# Finished: 880
# Incorrect signal length on song 882. Skipping
# Incorrect signal length on song 889. Skipping
# Finished: 890
# Finished: 900
# Incorrect signal length on song 907. Skipping
# Finished: 910
# Finished: 920
# Incorrect signal length on song 922. Skipping
# Finished: 930
# Incorrect signal length on song 940. Skipping
# Finished: 940
# Incorrect signal length on song 942. Skipping
# Incorrect signal length on song 946. Skipping
# Incorrect signal length on song 948. Skipping
# Incorrect signal length on song 949. Skipping
# Finished: 950
# Incorrect signal length on song 951. Skipping
# Incorrect signal length on song 956. Skipping
# Finished: 960
# Incorrect signal length on song 965. Skipping
# Incorrect signal length on song 970. Skipping
# Finished: 970
# Incorrect signal length on song 975. Skipping
# Finished: 980
# Incorrect signal length on song 990. Skipping
# Finished: 990
# Incorrect signal length on song 999. Skipping
# Finished: 1000
# Incorrect signal length on song 1001. Skipping
# Incorrect signal length on song 1002. Skipping
# Incorrect signal length on song 1010. Skipping
# Finished: 1010
# Incorrect signal length on song 1014. Skipping
# Incorrect signal length on song 1015. Skipping
# Incorrect signal length on song 1017. Skipping
# Incorrect signal length on song 1019. Skipping
# Finished: 1020
# Incorrect signal length on song 1023. Skipping
# Finished: 1030
# Incorrect signal length on song 1037. Skipping
# Finished: 1040
# Incorrect signal length on song 1050. Skipping
# Finished: 1050
# Incorrect signal length on song 1053. Skipping
# Incorrect signal length on song 1054. Skipping
# Incorrect signal length on song 1060. Skipping
# Finished: 1060
# Incorrect signal length on song 1067. Skipping
# Incorrect signal length on song 1069. Skipping
# Incorrect signal length on song 1070. Skipping
# Finished: 1070
# Incorrect signal length on song 1077. Skipping
# Incorrect signal length on song 1080. Skipping
# Finished: 1080
# Incorrect signal length on song 1085. Skipping
# Incorrect signal length on song 1087. Skipping
# Finished: 1090
# Incorrect signal length on song 1096. Skipping
# Incorrect signal length on song 1099. Skipping
# Finished: 1100
# Finished: 1110
# Incorrect signal length on song 1112. Skipping
# Incorrect signal length on song 1113. Skipping
# Finished: 1120
# Incorrect signal length on song 1130. Skipping
# Finished: 1130
# Finished: 1140
# Incorrect signal length on song 1142. Skipping
# Incorrect signal length on song 1144. Skipping
# Finished: 1150
# Incorrect signal length on song 1157. Skipping
# Finished: 1160
# Incorrect signal length on song 1163. Skipping
# Finished: 1170
# Incorrect signal length on song 1177. Skipping
# Finished: 1180
# Incorrect signal length on song 1183. Skipping
# Incorrect signal length on song 1190. Skipping
# Finished: 1190
# Incorrect signal length on song 1198. Skipping
# Finished: 1200
# Incorrect signal length on song 1203. Skipping
# Incorrect signal length on song 1208. Skipping
# Finished: 1210
# Finished: 1220
# Incorrect signal length on song 1228. Skipping
# Incorrect signal length on song 1229. Skipping
# Finished: 1230
# Finished: 1240
# Incorrect signal length on song 1241. Skipping
# Incorrect signal length on song 1243. Skipping
# Finished: 1250
# Incorrect signal length on song 1256. Skipping
# Incorrect signal length on song 1259. Skipping
# Finished: 1260
# Finished: 1270
# Incorrect signal length on song 1273. Skipping
# Finished: 1280
# Incorrect signal length on song 1283. Skipping
# Incorrect signal length on song 1286. Skipping
# Finished: 1290
# Incorrect signal length on song 1291. Skipping
# Incorrect signal length on song 1297. Skipping
# Incorrect signal length on song 1298. Skipping
# Incorrect signal length on song 1300. Skipping
# Finished: 1300
# Incorrect signal length on song 1304. Skipping
# Incorrect signal length on song 1308. Skipping
# Finished: 1310
# Finished: 1320
# Incorrect signal length on song 1326. Skipping
# Incorrect signal length on song 1328. Skipping
# Finished: 1330
# Incorrect signal length on song 1331. Skipping
# Incorrect signal length on song 1333. Skipping
# Incorrect signal length on song 1336. Skipping
# Incorrect signal length on song 1337. Skipping
# Finished: 1340
# Incorrect signal length on song 1343. Skipping
# Finished: 1350
# Incorrect signal length on song 1351. Skipping
# Incorrect signal length on song 1352. Skipping
# Incorrect signal length on song 1355. Skipping
# Finished: 1360
# Incorrect signal length on song 1362. Skipping
# Finished: 1370
# Incorrect signal length on song 1371. Skipping
# Incorrect signal length on song 1373. Skipping
# Finished: 1380
# Finished: 1390
# Incorrect signal length on song 1397. Skipping
# Finished: 1400
# Incorrect signal length on song 1407. Skipping
# Incorrect signal length on song 1409. Skipping
# Incorrect signal length on song 1410. Skipping
# Finished: 1410
# Incorrect signal length on song 1411. Skipping
# Incorrect signal length on song 1418. Skipping
# Finished: 1420
# Finished: 1430
# Incorrect signal length on song 1439. Skipping
# Finished: 1440
# Incorrect signal length on song 1441. Skipping
# Incorrect signal length on song 1448. Skipping
# Finished: 1450
# Incorrect signal length on song 1453. Skipping
# Incorrect signal length on song 1460. Skipping
# Finished: 1460
# Finished: 1470
# Finished: 1480
# Finished: 1490
# Incorrect signal length on song 1492. Skipping
# Incorrect signal length on song 1494. Skipping
# Incorrect signal length on song 1495. Skipping
# Finished: 1500
# Incorrect signal length on song 1501. Skipping
# Incorrect signal length on song 1504. Skipping
# Incorrect signal length on song 1505. Skipping
# Finished: 1510
# Incorrect signal length on song 1512. Skipping
# Incorrect signal length on song 1514. Skipping
# Incorrect signal length on song 1516. Skipping
# Incorrect signal length on song 1520. Skipping
# Finished: 1520
# Incorrect signal length on song 1522. Skipping
# Incorrect signal length on song 1525. Skipping
# Finished: 1530
# Incorrect signal length on song 1532. Skipping
# Incorrect signal length on song 1534. Skipping
# Incorrect signal length on song 1535. Skipping
# Finished: 1540
# Incorrect signal length on song 1543. Skipping
# Incorrect signal length on song 1544. Skipping
# Finished: 1550
# Incorrect signal length on song 1552. Skipping
# Incorrect signal length on song 1553. Skipping
# Incorrect signal length on song 1556. Skipping
# Finished: 1560
# Incorrect signal length on song 1564. Skipping
# Incorrect signal length on song 1565. Skipping
# Finished: 1570
# Incorrect signal length on song 1571. Skipping
# Incorrect signal length on song 1580. Skipping
# Finished: 1580
# Incorrect signal length on song 1584. Skipping
# Incorrect signal length on song 1586. Skipping
# Finished: 1590
# Incorrect signal length on song 1594. Skipping
# Finished: 1600
# Incorrect signal length on song 1603. Skipping
# Finished: 1610
# Incorrect signal length on song 1611. Skipping
# Incorrect signal length on song 1616. Skipping
# Finished: 1620

# %%
np.random.choice(2,1,replace = False)
# Out:
# array([1])

# %%
min(1,2)
# Out:
# 1

# %%
len(songs_split)
# Out:
# 297
